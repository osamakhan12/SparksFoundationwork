# %% [markdown]
# # Author: Muhammad Osama Khan
#
# # The Sparks Foundation. Data Science & Business Analytics Intern
#
#
# ## Task 3: As a business manager, try to find out the weak areas where you can work to make more profit.

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from win32com.client import Dispatch

# %% [markdown]
# # Load and Read Data

# %%
data = pd.read_csv('F:/Artificial Intelligence/sparksfoundation work/datasets/SampleSuperstore.csv')
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# # Exploring Data Analysis

# %% [markdown]
# # Understanding Data

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# # Checking Null Values and Cleaning Data

# %%
data.isnull()
# Out:
#       Ship Mode  Segment  Country   City  State  Postal Code  Region  \
# 0         False    False    False  False  False        False   False
# 1         False    False    False  False  False        False   False
# 2         False    False    False  False  False        False   False
# 3         False    False    False  False  False        False   False
# 4         False    False    False  False  False        False   False
# ...         ...      ...      ...    ...    ...          ...     ...
# 9989      False    False    False  False  False        False   False
# 9990      False    False    False  False  False        False   False
# 9991      False    False    False  False  False        False   False
# 9992      False    False    False  False  False        False   False
# 9993      False    False    False  False  False        False   False
#
#       Category  Sub-Category  Sales  Quantity  Discount  Profit
# 0        False         False  False     False     False   False
# ...

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# # Visualizing Data

# %%
sns.pairplot(data=data)

# %%
#shows countries from top
data['Country'].head()
# Out:
# 0    United States
# 1    United States
# 2    United States
# 3    United States
# 4    United States
# Name: Country, dtype: object

# %%
#shows cities
data['City'].value_counts().count()
# Out:
# 531

# %%
#shows states
data['State'].value_counts().count()
# Out:
# 49

# %%
#Visualizing by Ship Mode
sns.countplot(data['Ship Mode'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### As you can see, Superstore uses different Shiping classes.
# #### First Class, Standard Class,Third Class and Same Day.
# #### In which  Second class is used by maximum customer(about-5900 approx) and Same day is used by Minimum Customesr(about 500-800 approx).

# %%
data['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
#Visualizing By Segmentataion
sns.countplot(data['Segment'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### As you can see, Superstore is divided in to three segments. #### Consumer,Corporate Segment and Home Office.
# #### In which superstore has maximum segementaion in Consumer in terms of Count( > 5000).

# %%
#Visualizing by Region
sns.countplot(data['Region'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### From the graph it is clear that West Region has achieved the highest count in terms of supplies(> 3000).

# %%
data['Category'].describe()
# Out:
# count                9994
# unique                  3
# top       Office Supplies
# freq                 6026
# Name: Category, dtype: object

# %%
data['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
data['Segment'].describe()
# Out:
# count         9994
# unique           3
# top       Consumer
# freq          5191
# Name: Segment, dtype: object

# %%
#Visualizing by Pie Chart
plt.figure(figsize=(15,8))
plt.pie(data['Category'].value_counts(),labels=data['Category'].value_counts().index,startangle=90,
        shadow=True,explode=[0,0.1,0],autopct="%1.1f%%")
plt.show()

# %% [markdown]
# #### As you can see from the Pie chart,
# #### Supplies of "Office Suppies" Category is done maximum i.e. 60.3%.
# #### Than "Furniture" category has done 21.2% supplies
# #### Minimum supply is done in "Technology"Category i.e. 18.5%

# %%
data['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
plt.figure(figsize=(15,8))
plt.pie(data['Sub-Category'].value_counts(),labels=data['Sub-Category'].value_counts().index,
        shadow=True,autopct="%0.1f%%")
plt.show()

# %% [markdown]
# #### As you can see from the pie chart,
# #### The supply of 'Binders' has done maximunm i.e. 15.2%
# #### After that supply of 'Paper' has done  i.e. 13.7%
# #### After that supply of 'Furnishings' has done i.e. 9.6% and so on
# #### The minimin supply of 'Copiers' has done i.e. 0.7%

# %%
print("Total sales:",data['Sales'].sum())
print("Total Profit:",data['Profit'].sum())
print("Total Quantity:",data['Quantity'].sum())
# Out:
# Total sales: 2297200.8603
# Total Profit: 286397.0217
# Total Quantity: 37873

# %%
#In terms of Sales
sns.barplot(x='Category',y='Sales',hue='Region',data=data)
plt.title("Sales in terms of Categories in different Regions")
# Out:
# Text(0.5, 1.0, 'Sales in terms of Categories in different Regions')

# %% [markdown]
# #### As you can see from the graph,
# #### the sales of Furniture is done maximum in "Western Region" nearly about 360k+.
# #### after that, the sales of "Office Supplies" is maximum done in South region nearly about 150k+
# #### And at the end the suplies of "Technology" is maximum done in South Region nearly about 550k+.
# #### Among all the three Category, the sale of Technology is Max and also Max. Sales is done in South region

# %%
plt.figure(figsize=(20,8))
sns.barplot(x='Sub-Category',y='Sales',data=data)
plt.title("Sales in terms of Sub-Categories")
# Out:
# Text(0.5, 1.0, 'Sales in terms of Sub-Categories')

# %% [markdown]
# ####  Sales of Copiers has done Maximum nearly about 2350+.

# %%
plt.figure(figsize=(15,8))
plt.pie(data['Sales'].groupby(data.Region).sum(),labels=data['Sales'].groupby(data.Region).sum().index,
        shadow=True,autopct="%0.2f%%")
plt.title("Region Wise Sales")
plt.show()

# %% [markdown]
# #### As you can see in this Pie Chart
# #### West Region has done maximum
# #### After than East region
# #### After than Central region
# #### and at last Sounth region

# %%
# In terms of Profit
sns.barplot(x='Category',y='Profit',hue='Region',data=data)
plt.title("Profit in terms of Categories in different Regions")
# Out:
# Text(0.5, 1.0, 'Profit in terms of Categories in different Regions')

# %% [markdown]
# #### As we can see from the graph
# #### Furniture has make maximum profit in South Region,
# #### after that "Office Supplies" has make maximum profit in "Western Region"
# #### and at the end "Technology" has make maximum profit in Eastern Region.
# #### Among all these Category, "Technology has make maximum profit in all the four Region
# #### Furniture has make minimum profit in all the four Region.

# %%
plt.figure(figsize=(15,8))
plt.pie(data['Profit'].groupby(data.Region).sum(),labels=data['Profit'].groupby(data.Region).sum().index,shadow=True,autopct="%0.2f%%")
plt.title("Region Wise profit")
plt.show()

# %% [markdown]
# #### As you can see from the pie chart,
# #### West region has make maximum profit i.e. 37.86%
# #### After than East Region makes profit i.e. 31.96
# #### After than South Region makes Profit i.e.16.32%
# #### and Centeral region has make minimum profit i.e. 13.86%.

# %%
plt.figure(figsize=(15,8))
sns.barplot(x="Sub-Category",y="Profit",data=data,ci=0)
plt.title("Profit sub-category wise.")
plt.show()

# %% [markdown]
# #### Maximum profit is made by Copiers
# #### Minimum profit is made by Fasteners

# %%
#In terms of Sales
plt.figure(figsize=(10,8))
sns.barplot(x="Segment",y="Sales",data=data)
plt.title("Sales in Different Segment")
plt.show()

# %%
#In terms of Profit
plt.figure(figsize=(10,8))
sns.barplot(x="Segment",y="Profit",data=data)
plt.title("Profit in Different Segment")
plt.show()

# %% [markdown]
# #### As you can see, 'Homes office' has make maximum profit
# #### while "Consumer" has make minimum profit.

# %%
### In terms of Sales
plt.figure(figsize=(15,8))
sns.barplot(x="Category",y="Sales",data=data,hue="Ship Mode")
plt.title("Categories wise sales in different Shipmode")
# Out:
# Text(0.5, 1.0, 'Categories wise sales in different Shipmode')

# %% [markdown]
# #### As you can see, Sale of "Technology" has done maximum on same day ship mode while it is least in second class ship mode.
# #### Sale of "Furniture" has done maximum on second class ship mode while it is least in same day  ship mode.
# #### Sale of "Office supply" has done maximum on second class ship mode while it is least in same day ship mode.

# %%
# In terms of Profit
plt.figure(figsize=(15,8))
sns.barplot(x="Category",y="Profit",data=data,hue="Ship Mode",ci=0)
plt.title("Categories wise profit in different Shipmode")
# Out:
# Text(0.5, 1.0, 'Categories wise profit in different Shipmode')

# %% [markdown]
# #### As you can see,"Technology" has made maximum profit in First class and least in Second class.
# #### "Furniture" has made very least profit in all the shiping modes in which second class is prefered maximum by customers and same day is least prefered by customers.
# #### Office supply has made Maximum profit in Second class and Least profit in Standard class

# %%
### In terms of Sales
plt.figure(figsize=(10,8))
sns.barplot(x="Ship Mode",y="Sales",data=data)
plt.title("Sales in Different Ship Modes")
plt.show()

# %% [markdown]
# #### As you can see, Shiping on "Same Day" has Maximum sales
# #### after than Scond class Maximum sale
# #### while "Fisrt class" and "Standard Class" has almost equal Sales

# %%
#In terms oF Profit
sns.barplot(x='Ship Mode',y='Profit',data=data)
plt.show()

# %% [markdown]
# #### "First class" has make maximum profit while "standard class" has make minimum profit.

# %% [markdown]
# # Summary
# #### It is the Data of USA's Superstore,consisting of 49 States and 531 cities.
# #### Office Supplies has Maximum counts nearly about 60.3%.
# #### Consumer Segments has Maximum supplies and Homeoffice has Minimum Supplies.
# #### Total sales: 2297200.8603
# #### Total Profit: 286397.0217
# #### Total Quantity: 37873
# #### Western Region has achieved the highest count in terms of supplies and South Region has done Minimum Supplies.
# #### Office Supplies has Maximum supplies while Technology has Minimum Supplies.
# #### Technology has Maximum Sales in all the four Regions.
# #### West Region has done Maximum Sales.
# #### Technology has made maximum profit in all the four Regions.
# #### West region has made maximum profit i.e. 37.86% and Centeral region has made minimum profit i.e. 13.86%.
# #### Technology has made maximum profit in all the four Shipmodes.
# #### Homeoffice had done maximum sales and profit while Consumers has done Minimum sale and making minimum profit.
# #### Shiping on "Same Day" has Maximum sales while "Fisrt class" and "Second Class" has almost equal Sales.
# #### Shiping on "First Class" has made Maximum Profit while "Standard Class" had made Minimum Profit.
# #### Shiping of "Technology" has made maximum sale and profit in all the four Ship Modes.

# %% [markdown]
# # Problem Satetment:
# #### As a business Manager,try to find out the Weak areas where you can work to make more profit. What all business problems you can derive by exploring the data?

# %% [markdown]
# # Solution
# #### As we find out from the Analysis that, Technology are doing maximum sales and also making maximum profit. So, in this, Category which have minimum sales and profit,we have to increase their supplies,then only we will get profit from them. Secondly, The ship Mode which is Maximum use by customers are Same day and they are doing maximum sales but do not making any much profit. While First Class is least prefered and also doing less sales but they are making Maximum profit because the Shiping Price of First Calss is more than the other Ship Modes.Also, the supplies of technology is the main reason for growth of profit in First Class because the shiping of these product need much care as they are very costly , so,people generally prefered this type of ship mode.In order to get the more profit from the other ship modes, we have to increase the shiping Prices. Also, Homeoffice segment has done the maximum sales and making the maximum profit while consumers are the lest one.So, we have to decrease the suppies in Consumer Segment as they are not making much profit and increase the supplies in other two segments. Also, the Region who have the more sales but do not making any profit.Either,we have to increase the selling price in those Regions or else reduce the supplies as they are not makeing much profit.

# %%
x
